# %%
from matplotlib.pylab import plt

# %%
losses = []
maps = []
with open("./I3D/outputs/R50_raw_64x2/stdout.log") as f:
#with open("/home/soroush/Projects/slowfast/fixed_experiments/raw/stdout.log") as f:
    lines = f.readlines()
    
    for line in lines:
        if "loss" in line:
            num = line.split(" ")[-3][0:-1]
            losses.append(float(num))
            
        if "\"map\"" in line:
            num = line.split(" ")[-3][0:-1]
            maps.append(float(num))

# %%
plt.plot(losses)
plt.title("loss curve")
plt.xlabel("iter")
plt.ylabel("loss")
plt.ylim(0, 0.06)
print(len(losses))
# Out:
# 7840

# %%
print(maps)
plt.plot([x*5 for x in range(len(maps))], maps)
plt.title("validation mAP curve")
plt.xlabel("epoch")
plt.ylabel("mAP")
print(len(maps))
# Out:
# [0.41671, 0.49104, 0.44093, 0.43519, 0.4491, 0.44065, 0.54924, 0.57321, 0.57586, 0.57297, 0.56728, 0.57916, 0.56343, 0.57076, 0.56738, 0.57059, 0.59897]
# 17

# %%
for idx, val in enumerate(maps):
    print((idx+1)*5, val)
# Out:
# 5 0.41671
# 10 0.49104
# 15 0.44093
# 20 0.43519
# 25 0.4491
# 30 0.44065
# 35 0.54924
# 40 0.57321
# 45 0.57586
# 50 0.57297
# 55 0.56728
# 60 0.57916
# 65 0.56343
# 70 0.57076
# 75 0.56738
# 80 0.57059
# 85 0.59897
