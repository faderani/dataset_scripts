# %%
from matplotlib.pylab import plt

# %%
losses = []
maps = []
with open("./I3D/outputs/R50_hands_obj_16x8/stdout.log") as f:
#with open("/home/soroush/Projects/slowfast/fixed_experiments/raw/stdout.log") as f:
    lines = f.readlines()
    
    for line in lines:
        if "loss" in line:
            num = line.split(" ")[-3][0:-1]
            losses.append(float(num))
            
        if "\"map\"" in line:
            num = line.split(" ")[-3][0:-1]
            maps.append(float(num))

# %%
plt.plot(losses)
plt.title("loss curve")
plt.xlabel("iter")
plt.ylabel("loss")
plt.ylim(0, 0.06)
print(len(losses))
# Out:
# 2820

# %%
print(maps)
plt.plot([x*5 for x in range(len(maps))], maps)
plt.title("validation mAP curve")
plt.xlabel("epoch")
plt.ylabel("mAP")
print(len(maps))
# Out:
# [0.31345, 0.42799, 0.44027, 0.46944, 0.46927, 0.46473, 0.56072, 0.57485, 0.56793, 0.57738, 0.57505, 0.58067]
# 12

# %%
for idx, val in enumerate(maps):
    print((idx+1)*5, val)
# Out:
# 5 0.36218
# 10 0.49281
# 15 0.49894
# 20 0.54676
# 25 0.50644
# 30 0.5047
# 35 0.59045
# 40 0.59904
# 45 0.60295
# 50 0.59865
# 55 0.59698
# 60 0.60897
